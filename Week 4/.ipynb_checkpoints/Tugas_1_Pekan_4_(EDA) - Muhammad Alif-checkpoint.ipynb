# %% [markdown]
# # Soal 1. Menentukan jenis data categorical atau numeric
# Jelaskan data kategorikal (kualitatif) dan data numerik (kuantitatif)

# %% [markdown]
# Jawab disini:

# %% [markdown]
# Data kategorikal adalah data yang dikelompokkan berdasarkan ciri tertentu seperti nama karyawan, jenis kelamin, tempat tinggal, lulus atau gagal yang bukan data pengukuran. Data kategorikal terdiri dari data nominal dan ordinal.
#
# Data numerik adalah data yang terdiri dar angka-angka yang menggambarkan kuantitas. kelompok data numerik dapat menerima operasi matematik. Data numerik terdiri dari data diskrit dan kontinu.

# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=19Yc404D3U3OPPoUP8J1pXETlTmA4hOOX)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset/austin_weather.csv',na_values=['na','-'])
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0  12/21/2013         74      60.0        45           67.0          49.0
# 1  12/22/2013         56      48.0        39           43.0          36.0
# 2  12/23/2013         58      45.0        32           31.0          27.0
# 3  12/24/2013         61      46.0        31           36.0          28.0
# 4  12/25/2013         58      50.0        41           44.0          40.0
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0          43.0                 93.0                75.0                57.0
# 1          28.0                 93.0                68.0                43.0
# 2          23.0                 76.0                52.0                27.0
# 3          21.0                 89.0                56.0                22.0
# 4          36.0                 86.0                71.0                56.0
#
#    ...  SeaLevelPressureAvgInches  SeaLevelPressureLowInches  \
# 0  ...                      29.68                      29.59
# 1  ...                      30.13                      29.87
# 2  ...                      30.49                      30.41
# 3  ...                      30.45                      30.30
# 4  ...                      30.33                      30.27
#
#    VisibilityHighMiles  VisibilityAvgMiles  VisibilityLowMiles  WindHighMPH  \
# 0                 10.0                 7.0                 2.0         20.0
# 1                 10.0                10.0                 5.0         16.0
# 2                 10.0                10.0                10.0          8.0
# 3                 10.0                10.0                 7.0         12.0
# 4                 10.0                10.0                 7.0         10.0
#
#    WindAvgMPH  WindGustMPH  PrecipitationSumInches               Events
# 0         4.0         31.0                    0.46  Rain , Thunderstorm
# 1         6.0         25.0                       0
# 2         3.0         12.0                       0
# 3         4.0         20.0                       0
# 4         2.0         16.0                       T
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1312 non-null   float64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1312 non-null   float64
#  5   DewPointAvgF                1308 non-null   float64
#  6   DewPointLowF                1312 non-null   float64
#  7   HumidityHighPercent         1317 non-null   float64
#  8   HumidityAvgPercent          1309 non-null   float64
#  9   HumidityLowPercent          1317 non-null   float64
#  10  SeaLevelPressureHighInches  1316 non-null   float64
#  11  SeaLevelPressureAvgInches   1316 non-null   float64
#  12  SeaLevelPressureLowInches   1316 non-null   float64
#  13  VisibilityHighMiles         1307 non-null   float64
#  14  VisibilityAvgMiles          1307 non-null   float64
#  15  VisibilityLowMiles          1307 non-null   float64
#  16  WindHighMPH                 1317 non-null   float64
#  17  WindAvgMPH                  1306 non-null   float64
#  18  WindGustMPH                 1315 non-null   float64
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: float64(16), int64(2), object(3)
# memory usage: 216.5+ KB

# %%
df = df.sample(1000)
df.isna()
# Out:
#        Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 682   False      False     False     False          False         False
# 179   False      False     False     False          False         False
# 896   False      False     False     False          False         False
# 63    False      False     False     False          False         False
# 884   False      False     False     False          False         False
# ...     ...        ...       ...       ...            ...           ...
# 321   False      False     False     False          False         False
# 1019  False      False     False     False          False         False
# 166   False      False      True     False          False         False
# 867   False      False     False     False          False         False
# 916   False      False     False     False          False         False
#
#       DewPointLowF  HumidityHighPercent  HumidityAvgPercent  \
# 682          False                False               False
# 179          False                False               False
# 896          False                False               False
# 63           False                False               False
# 884          False                False               False
# ...            ...                  ...                 ...
# 321          False                False               False
# 1019         False                False               False
# 166          False                False               False
# 867          False                False               False
# 916          False                False               False
#
#       HumidityLowPercent  ...  SeaLevelPressureAvgInches  \
# 682                False  ...                      False
# 179                False  ...                      False
# 896                False  ...                      False
# 63                 False  ...                      False
# 884                False  ...                      False
# ...                  ...  ...                        ...
# 321                False  ...                      False
# 1019               False  ...                      False
# 166                False  ...                      False
# 867                False  ...                      False
# 916                False  ...                      False
#
#       SeaLevelPressureLowInches  VisibilityHighMiles  VisibilityAvgMiles  \
# 682                       False                False               False
# 179                       False                False               False
# 896                       False                False               False
# 63                        False                False               False
# 884                       False                False               False
# ...                         ...                  ...                 ...
# 321                       False                False               False
# 1019                      False                False               False
# 166                       False                False               False
# 867                       False                False               False
# 916                       False                False               False
#
#       VisibilityLowMiles  WindHighMPH  WindAvgMPH  WindGustMPH  \
# 682                False        False       False        False
# 179                False        False       False        False
# 896                False        False       False        False
# 63                 False        False       False        False
# 884                False        False       False        False
# ...                  ...          ...         ...          ...
# 321                False        False       False        False
# 1019               False        False       False        False
# 166                False        False       False        False
# 867                False        False       False        False
# 916                False        False       False        False
#
#       PrecipitationSumInches  Events
# 682                    False   False
# 179                    False   False
# 896                    False   False
# 63                     False   False
# 884                    False   False
# ...                      ...     ...
# 321                    False   False
# 1019                   False   False
# 166                    False   False
# 867                    False   False
# 916                    False   False
#
# [1000 rows x 21 columns]

# %% [markdown]
# <h2>Soal 2. Visualisasi Scatter Plot dengan memiliki missing value </h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' dan 'na' yang dianggap sebagai missing value,  namun data ini tidak bisa di ubah ke bentuk float, maka ubahlah data tersebut menjadi NaN dengan menambahkan argumen na_values=['na', '-'] saat menggunakan atribut pd.read_csv('nama file.csv'. na_values=..]
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# a. Buahlah visualisasi scatter plot menggunakan sample(1000), sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# b. Kemudian bandingkan data visualisasi diatas dengan visualisasi data (sample=1000) setelah handling missing value menggunakan:
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html

# %%
# convert tipe data ke float
df_selected = df[['DewPointAvgF','HumidityAvgPercent','TempAvgF','WindAvgMPH']].reset_index(drop=True)
df_selected.astype('float').dtypes
df_selected.head()
# Out:
#    DewPointAvgF  HumidityAvgPercent  TempAvgF  WindAvgMPH
# 0          59.0                74.0      69.0         3.0
# 1          72.0                68.0      85.0         9.0
# 2          68.0                76.0      77.0         5.0
# 3          46.0                53.0      63.0         6.0
# 4          72.0                84.0      78.0         7.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.scatter(df_selected['HumidityAvgPercent'],y=df_selected['DewPointAvgF'],
            cmap='coolwarm',c=df_selected['TempAvgF'],s=(df_selected['WindAvgMPH'])*20)
plt.title('Austin Weather before handling missing values')
plt.xlabel('Humidity Average (%)')
plt.ylabel('Dew Point Average (F)')
# Out:
# Text(0, 0.5, 'Dew Point Average (F)')

# %%
# after handling missing values
df_handled = df_selected.fillna(method='ffill')

plt.figure(figsize=(12,8))
plt.scatter(df_handled['HumidityAvgPercent'],y=df_handled['DewPointAvgF'],
            cmap='coolwarm',c=df_handled['TempAvgF'],s=(df_handled['WindAvgMPH'])*20)
plt.title('Austin Weather after handling missing values')
plt.xlabel('Humidity Average (%)')
plt.ylabel('Dew Point Average (F)')
# Out:
# Text(0, 0.5, 'Dew Point Average (F)')

# %% [markdown]
# #                     **Expected output**
#
# #                     **Tanpa Handling missing value**
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1FYJkCwAfm8f3jyNdzOnCvp15hS_DixHr)
#
# ##                    **Dengan Handling missing value**
# ![dengan handling missing value](https://drive.google.com/uc?id=1nqZuPdBsqSsOud-_XuBGujDAcJWEEvIr)

# %%
# code here
import numpy as np

myData = [2,3,5,4,7,4,0,12,23,78,45,119,235,653,43,1]
outliers = []

def check_outliers(data):
    data = sorted(data)
    q1 = np.percentile(data,25)
    q3 = np.percentile(data,75)
    print('q1, q3: ',q1,',', q3)
    IQR = q3 - q1
    print('IQR: ', IQR)
    lb = q1 - (1.5*IQR)
    ub = q3 + (1.5*IQR)
    print('lower bound:', lb)
    print('upper bound:', ub)
    for i in data:
        if (i<lb or i>ub):
            outliers.append(i)
    return outliers

data_outliers = check_outliers(myData)
print('Outlier pada data:', data_outliers)

plt.boxplot(myData,vert=False)
# Out:
# q1, q3:  3.75 , 53.25
# IQR:  49.5
# lower bound: -70.5
# upper bound: 127.5
# Outlier pada data: [235, 653]
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9b76d16c8>,
#   <matplotlib.lines.Line2D at 0x1f9b76d15c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f9b76b5608>,
#   <matplotlib.lines.Line2D at 0x1f9b76d1ac8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9b76d10c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9b7699448>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9b76d1588>],
#  'means': []}

# %% [markdown]
# Analisa :

# %% [markdown]
# Download [price.csv](https://drive.google.com/uc?export=download&id=1LfuQmLb8AZxAvJzgWJ3u4h49EoTGqO-R)

# %%
df2 = pd.read_csv('dataset/price.csv')
df2.head()
# Out:
#    Observation  Dist_Taxi  Dist_Market  Dist_Hospital  Carpet  Builtup  \
# 0            1     9796.0       5250.0        10703.0  1659.0   1961.0
# 1            2     8294.0       8186.0        12694.0  1461.0   1752.0
# 2            3    11001.0      14399.0        16991.0  1340.0   1609.0
# 3            4     8301.0      11188.0        12289.0  1451.0   1748.0
# 4            5    10510.0      12629.0        13921.0  1770.0   2111.0
#
#         Parking City_Category  Rainfall  House_Price
# 0          Open         CAT B       530      6649000
# 1  Not Provided         CAT B       210      3982000
# 2  Not Provided         CAT A       720      5401000
# 3       Covered         CAT B       620      5373000
# 4  Not Provided         CAT B       450      4662000

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3. Visualisasi Data with Handling outliers </h2>
#
# Pada tugas kali ini, kita akan melakukan handling outliers. Outliers ditemukan pada kolom 'House_Price' dengan menggunakan boxplot dari library seaborn seperti gambar berikut:
#
#
# ![boxplot1](https://drive.google.com/uc?id=1y2jRwf8zRPXQtSBkmjJLcqUm4l6DR7d9)
#
#
# Dengan menggunakan Interquartile range, kita bisa temukan nilai data outliers dan meremove data outlier tersebut.
#
# *   Tentukan nilai batas atas dan batas bawah dari Interquartile range tersebut
# *   Remove data outliers tersebut menggunakan batas atas dan batas bawah
# *   Visualisasikan hasil data yang sudah d remove outliers seperti expected berikut:

# %%
plt.figure(figsize=(8,6))
plt.boxplot(df2['House_Price'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9b95f4f08>,
#   <matplotlib.lines.Line2D at 0x1f9b4325d88>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f9b9612a88>,
#   <matplotlib.lines.Line2D at 0x1f9b950e208>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9b79673c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9b96129c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9b7819508>],
#  'means': []}

# %% [markdown]
# **EXPECTED OUTPUT:**
#
# Batas bawah & batas atas:
#
# 871625.0 10976625.0
#
# Visualisasi boxplot:
#
# ![boxplot2](https://drive.google.com/uc?id=1qZc-lEa5FUzSQ_cyt4_GJQ0TZ8c6WjHX)

# %%
#Code here
import numpy as np
import matplotlib.pyplot as plt

def get_lower_upper_bound(data):
    q1 = np.percentile(data,25)
    q3 = np.percentile(data,75)
    iqr = q3-q1
    upper_bd = q3 + (1.5*iqr)
    lower_bd = q1 - (1.5*iqr)
    return lower_bd, upper_bd

batas_bawah, batas_atas = get_lower_upper_bound(df2['House_Price'])
print('Batas bawah & batas atas')
print(batas_bawah, batas_atas)
# Out:
# Batas bawah & batas atas
# 871625.0 10976625.0

# %%
# remove outliers
df_no_outliers = df2[(df2['House_Price'] > batas_bawah) & (df2['House_Price'] < batas_atas)]
df_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 933 entries, 0 to 935
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Observation    933 non-null    int64
#  1   Dist_Taxi      921 non-null    float64
#  2   Dist_Market    921 non-null    float64
#  3   Dist_Hospital  933 non-null    float64
#  4   Carpet         926 non-null    float64
#  5   Builtup        919 non-null    float64
#  6   Parking        933 non-null    object
#  7   City_Category  933 non-null    object
#  8   Rainfall       933 non-null    int64
#  9   House_Price    933 non-null    int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 80.2+ KB

# %%
sns.boxplot(data=df_no_outliers, x='House_Price')
# Out:
# <AxesSubplot:xlabel='House_Price'>
